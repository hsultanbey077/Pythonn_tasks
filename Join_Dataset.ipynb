# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Загружаем данные

# %%
first = pd.read_excel('Desktopfirst.xlsx')
second = pd.read_excel('Desktopsecond.xlsx')
third = pd.read_excel('Desktopthird.xlsx') 
fouth = pd.read_excel('Desktopfouth.xlsx')
fifth = pd.read_excel('Desktopfifth.xlsx')
sixth = pd.read_excel('Desktopsixth.xlsx')
seventh = pd.read_excel('Desktopseventh.xlsx')
eigth = pd.read_excel('Desktopeigth.xlsx')
ninth = pd.read_excel('Desktopninth.xlsx')
ten = pd.read_excel('Desktoptenth.xlsx')

# %%
final = pd.concat([first,second,third,fouth,fifth,sixth,seventh,eigth,ninth,ten],axis=0)

# %%
final.drop(columns=['Unnamed: 0'],axis=0,inplace=True)

# %%
final
# Out:
#       №             Наименование потенциального поставщика       БИН/ИИН  \
# 0   467  Товарищество с ограниченной ответственностью "...  160540016411
# 1   498                               ТОО "БЭСТ-Астана-НС"   40740005657
# 2   502  Товарищество с ограниченной ответственностью"G...   70540008075
# 3   517                                    ТОО "Гражданин"   90540008881
# 4   526  Товарищество с ограниченной ответственностью "...  110740014027
# ..  ...                                                ...           ...
# 4   873                                      ТОО "MSSP.GL"  150140024604
# 5   561                      ТОО "KAZPROTECT" (КАЗПРОТЕКТ)  140440021222
# 6   839                                       ТОО "PDMnet"  110740011449
# 7   798  Товарищество с ограниченной ответственностью "...   20940002804
# 8   681                                  AS & ER GRADE ТОО  120940007043
#
#     ИИН Руководителя                             ФИО  \
# ...

# %% [markdown]
# ## Удаляем дупликаты

# %%
final.drop(columns=['№'],axis=0,inplace=True)

# %%
final.drop_duplicates(keep=False,inplace=True)

# %%
len(final)
# Out:
# 365

# %%
final
# Out:
#                Наименование потенциального поставщика       БИН/ИИН  \
# 0   Товарищество с ограниченной ответственностью "...  160540016411
# 2   Товарищество с ограниченной ответственностью"G...   70540008075
# 3                                     ТОО "Гражданин"   90540008881
# 4   Товарищество с ограниченной ответственностью "...  110740014027
# 5                           ТОО "KazBioServis-Astana"  130740024484
# ..                                                ...           ...
# 4                                       ТОО "MSSP.GL"  150140024604
# 5                       ТОО "KAZPROTECT" (КАЗПРОТЕКТ)  140440021222
# 6                                        ТОО "PDMnet"  110740011449
# 7   Товарищество с ограниченной ответственностью "...   20940002804
# 8                                   AS & ER GRADE ТОО  120940007043
#
#     ИИН Руководителя                             ФИО  \
# 0       870811351023       КОЖАНТАЕВ АЙДАР АСКАРОВИЧ
# ...

# %%
final.to_excel(r'Desktop\final.xlsx')
